# %%
import sys
sys.path.append("..")

import config
from src.loader import load_reviews
from src.preprocessing import clean
from src.analysis import data_quality
from src.plots import rating_histogram, text_length_histogram, reviews_over_time

# %% [markdown]
# # Loading reviews dataset and metadata

# %%
# meta_ds = load_dataset(
#     "McAuley-Lab/Amazon-Reviews-2023",
#     "raw_meta_Electronics",
#     streaming=False,
#     trust_remote_code=True
# )

# meta_df = meta_ds["full"].to_pandas()
# print(meta_df.shape)

# %%
df = load_reviews(config.DATASET_NAME, config.SUBSET, n=config.N_SAMPLES)
print("Shape (raw):", df.shape)
# Out:
# Shape (raw): (20000, 10)

# %%
df.head()
# Out:
#    rating                                        title  \
# 0     3.0            Smells like gasoline! Going back!
# 1     1.0      Didn’t work at all lenses loose/broken.
# 2     5.0                                   Excellent!
# 3     5.0                       Great laptop backpack!
# 4     5.0  Best Headphones in the Fifties price range!
#
#                                                 text  \
# 0  First & most offensive: they reek of gasoline ...
# 1  These didn’t work. Idk if they were damaged in...
# 2  I love these. They even come with a carry case...
# 3  I was searching for a sturdy backpack for scho...
# 4  I've bought these headphones three times becau...
#
#                                               images        asin parent_asin  \
# 0  [{'small_image_url': 'https://m.media-amazon.c...  B083NRGZMM  B083NRGZMM
# 1                                                 []  B07N69T6TM  B07N69T6TM
# ...

# %%
df.dtypes
# Out:
# rating               float64
# title                    str
# text                     str
# images                object
# asin                     str
# parent_asin              str
# user_id                  str
# timestamp              int64
# helpful_vote           int64
# verified_purchase       bool
# dtype: object

# %%
df = clean(df)
print("Shape (clean):", df.shape)
# Out:
# Shape (clean): (19995, 11)

# %%
df[["rating", "helpful_vote", "text_len", "title_len"]].describe()
# Out:
#              rating  helpful_vote      text_len     title_len
# count  19995.000000  19995.000000  19995.000000  19995.000000
# mean       4.324181      1.544736    417.356689     25.973793
# std        1.202899     12.585152    660.034481     19.310106
# min        1.000000      0.000000      1.000000      1.000000
# 25%        4.000000      0.000000     70.000000     11.000000
# 50%        5.000000      0.000000    192.000000     20.000000
# 75%        5.000000      1.000000    463.500000     35.000000
# max        5.000000    777.000000   9989.000000    174.000000

# %%
df.columns
# Out:
# Index(['rating', 'title', 'text', 'asin', 'parent_asin', 'user_id',
#        'timestamp', 'helpful_vote', 'verified_purchase', 'text_len',
#        'title_len'],
#       dtype='str')

# %%
data_quality(df)
# Out:
# --- Missing values ---
# rating               0
# title                0
# text                 0
# asin                 0
# parent_asin          0
# user_id              0
# timestamp            0
# helpful_vote         0
# verified_purchase    0
# text_len             0
# title_len            0
# dtype: int64
#
# Empty strings (text): 0
# Empty strings (title): 0
#
# Duplicates (user_id + asin): 0
# Duplicates (full row): 0
#
# Date range: 2001-08-11 → 2023-03-18
# Unique products (asin): 16969
# Unique users: 2850
# Verified purchase: {True: 14400, False: 5595}
#
# --- Rating distribution ---
# rating
# 1.0     1458
# 2.0      740
# 3.0     1307
# 4.0     2847
# 5.0    13643
# Name: count, dtype: int64

# %%
rating_histogram(df).show()

# %%
text_length_histogram(df).show()

# %%
reviews_over_time(df).show()
